# %% [markdown]
# # Chapter 5
# # Tidy data and iteration
# 이번 장에서는 데이터를 다루는(변형, 조작, 정제 등) 법을 4장에 이어서 추가로 배운다.<br>
# 먼저 Tidy data에 대해서 설명한다

# %% [markdown]
# ### 5.1	Tidy data
# ### 5.1.1 Motivation
# Tidy data를 설명하기 위해서, 책에 있는 말을 가져오면 다음과 같다.<br>
# The data in Table 5.1 are tidy because they are organized according to two simple rules.
# 1. **The rows**, called **cases** or **observations**, each refer to a specific, unique, and similar sort of thing, e.g., girls named Elynor in 1935.
# 2. **The columns**, called **variables**, each have the same sort of value recorded for each row. For instance, n gives the number of babies for each case; sex tells which gender was assigned at birth.

# %%
import os
import warnings
import pandas as pd

# %%
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                    'B': {0: 1, 1: 3, 2: 5},
                    'C': {0: 2, 1: 4, 2: 6}})

# %% [markdown]
# #### 아래 데이터는 A가 있고, A의 값이 B 혹은 C와 함께 했을 때 값을 나타낸다.

# %%
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars=['A'], value_vars=['B'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %% [markdown]
# #### 아래와 같이 A와 만나는 변수 및 값으로 변형하여 나타내어 Tidy한 데이터가 되도록 한다.

# %%
pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %% [markdown]
# ### 그리고 babynames라는 dataset이 있는데, 이를 이름과 성으로 groupby 해준다.

# %%
dataset = "babynames.csv"
wd = os.getcwd()

babynames=pd.read_csv(os.path.join(wd, dataset), encoding = "ISO-8859-1")

# %%
babynames.head()
# Out:
#    year sex       name     n      prop
# 0  1880   F       Mary  7065  0.072384
# 1  1880   F       Anna  2604  0.026679
# 2  1880   F       Emma  2003  0.020521
# 3  1880   F  Elizabeth  1939  0.019866
# 4  1880   F     Minnie  1746  0.017888

# %% [markdown]
# #### 방법 1 - groupby 후 column에 대해서 sum

# %%
Spreads = babynames.groupby(["sex", "name"])["n"].sum().reset_index()
Spreads = Spreads.sort_values(by=["n"], ascending=False).reset_index()
Spreads.head()
# Out:
#    index sex     name        n
# 0  84125   M    James  5150472
# 1  86197   M     John  5115466
# 2  99151   M   Robert  4814815
# 3  93963   M  Michael  4350824
# 4  41737   F     Mary  4123200

# %% [markdown]
# #### 방법 2 - groupby 후 aggregation 적용
# 사실 같은 방법이지만, 개인적으로 aggregation이 편리하다고 생각.

# %%
Spreads = babynames.groupby(["sex", "name"], as_index=False).agg({"n": "sum"})
Spreads = Spreads.sort_values(by=["n"], ascending=False).reset_index()
Spreads.head()
# Out:
#    index sex     name        n
# 0  84125   M    James  5150472
# 1  86197   M     John  5115466
# 2  99151   M   Robert  4814815
# 3  93963   M  Michael  4350824
# 4  41737   F     Mary  4123200

# %%
Spreads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107973 entries, 0 to 107972
# Data columns (total 4 columns):
# index    107973 non-null int64
# sex      107973 non-null object
# name     107973 non-null object
# n        107973 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ MB

# %% [markdown]
# #### 그리고 중요한 것이 바로, Variable이 두 가지로 나뉜다는 것
# - **Categorical variables** record type or category and often take the form of a word.
# - **Quantitative variables** record a numerical attribute. A quantitative variable is just
# what it sounds like: a number.
#
# 위 DataFrame을 살펴보면, Categorical type으로 지정된 column이 없는데, 사실 성별의 경우 categorical type 이므로 지정해주는 것이 좋다.

# %% [markdown]
# ### 5.2	Reshaping data

# %% [markdown]
# ###  5.2.3 Gathering
# spread는 위에서 봤었던 melt에 해당하고, gather는 그의 반대인 pivot을 통해서 narrow한 것을 wide하게 할 수 있다.

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                            'two'],
                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                    'baz': [1, 2, 3, 4, 5, 6],
                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %% [markdown]
# ### 교재에서 R에서 하는 반복문에 대해서 나오는데 이는 통째로 생략

# %%
Teams = pd.read_csv("Teams.csv")
Teams.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
Teams = Teams[["yearID", "teamID", "W", "L", "R", "RA"]]
Teams = Teams[(Teams["yearID"] >= 1954)]
Teams = Teams.rename(columns= {"R" : "RS"})
Teams["WPct"] = Teams["W"] / (Teams["W"] + Teams["L"])
Teams["run_ratio"] = (Teams["RS"] / Teams["RA"])

Teams.reset_index()
# Out:
#       index  yearID teamID   W    L   RS   RA      WPct  run_ratio
# 0      1247    1954    BAL  54  100  483  668  0.350649   0.723054
# 1      1248    1954    BOS  69   85  700  728  0.448052   0.961538
# 2      1249    1954    BRO  92   62  778  740  0.597403   1.051351
# 3      1250    1954    CHA  94   60  711  521  0.610390   1.364683
# 4      1251    1954    CHN  64   90  700  766  0.415584   0.913838
# ...     ...     ...    ...  ..  ...  ...  ...       ...        ...
# 1643   2890    2018    SLN  88   74  759  691  0.543210   1.098408
# 1644   2891    2018    TBA  90   72  716  646  0.555556   1.108359
# 1645   2892    2018    TEX  67   95  737  848  0.413580   0.869104
# 1646   2893    2018    TOR  73   89  709  832  0.450617   0.852163
# 1647   2894    2018    WAS  82   80  771  682  0.506173   1.130499
#
# [1648 rows x 9 columns]

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure(figsize=(16, 8))
ax = sns.regplot(x="run_ratio", y="WPct", data=Teams)
ax.set(xlabel="Ratio of Runs Scored to Runs Allowed", ylabel="Winning Percentage")
# Out:
# [Text(0, 0.5, 'Winning Percentage'),
#  Text(0.5, 0, 'Ratio of Runs Scored to Runs Allowed')]

# %%
Teams = pd.read_csv("Teams.csv")
Teams.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
Teams = Teams[(Teams["yearID"] >= 1916)]

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=Teams, x="yearID", y="HR", hue="lgID", linewidth=2.5)

# %% [markdown]
# ##  5.5	Data intake
# 다른 부분보다도 HTML Table Parsing에 집중하여

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# <img src="./table.PNG" width="500" height="500">

# %%
url="https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# Parse the html content
soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify()) # print the parsed data of html
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of countries by GDP (nominal) - Wikipedia
#   </title>
#   <script>
# ...

# %% [markdown]
# #### HTML 코드 내에서 표에 대한 정보는 대개 `<tr>` 태그 내에 있다

# %%
gdp_table = soup.find("table", attrs={"class": "wikitable"})
gdp_table_data = gdp_table.tbody.find_all("tr")  # contains 2 rows

# Get all the headings of Lists
headings = []
for td in gdp_table_data[0].find_all("td"):
    # remove any newlines and extra spaces from left and right
    headings.append(td.b.text.replace('\n', ' ').strip())

print(headings)
# Out:
# ['Per the International Monetary Fund (2019 estimates)', 'Per the World Bank (2018)', 'Per the United Nations (2017)']

# %%
data = {}
for table, heading in zip(gdp_table_data[1].find_all("table"), headings):
    # Get headers of table i.e., Rank, Country, GDP.
    t_headers = []
    for th in table.find_all("th"):
        # remove any newlines and extra spaces from left and right
        t_headers.append(th.text.replace('\n', ' ').strip())
    # Get all the rows of table
    table_data = []
    for tr in table.tbody.find_all("tr"): # find all tr's from table's tbody
        t_row = {}
        # Each table row is stored in the form of
        # t_row = {'Rank': '', 'Country/Territory': '', 'GDP(US$million)': ''}

        # find all td's(3) in tr and zip it with t_header
        for td, th in zip(tr.find_all("td"), t_headers): 
            t_row[th] = td.text.replace('\n', '').strip()
        table_data.append(t_row)

    # Put the data for the table with his heading.
    data[heading] = table_data

print(data)
# Out:
# {'Per the International Monetary Fund (2019 estimates)': [{}, {'Rank': '', 'Country/Territory': 'World[19]', 'GDP(US$million)': '87,265,226'}, {'Rank': '1', 'Country/Territory': 'United States', 'GDP(US$million)': '21,439,453'}, {'Rank': '—', 'Country/Territory': 'European Union[23][n 1]', 'GDP(US$million)': '18,705,132'}, {'Rank': '2', 'Country/Territory': 'China[n 2]', 'GDP(US$million)': '14,140,163'}, {'Rank': '3', 'Country/Territory': 'Japan', 'GDP(US$million)': '5,154,475'}, {'Rank': '4', 'Country/Territory': 'Germany', 'GDP(US$million)': '3,863,344'}, {'Rank': '5', 'Country/Territory': 'India', 'GDP(US$million)': '2,935,570'}, {'Rank': '6', 'Country/Territory': 'United Kingdom', 'GDP(US$million)': '2,743,586'}, {'Rank': '7', 'Country/Territory': 'France', 'GDP(US$million)': '2,707,074'}, {'Rank': '8', 'Country/Territory': 'Italy', 'GDP(US$million)': '1,988,636'}, {'Rank': '9', 'Country/Territory': 'Brazil', 'GDP(US$million)': '1,847,020'}, {'Rank': '10', 'Country/Territory': 'C
# ...

# %%
pd.DataFrame(data["Per the World Bank (2018)"]).dropna()
# Out:
#     Rank Country/Territory GDP(US$million)
# 1                    World      85,804,391
# 2      1     United States      20,494,100
# 3      2        China[n 5]      13,608,152
# 4      3             Japan       4,970,916
# 5      4           Germany       3,996,759
# ..   ...               ...             ...
# 187  181             Palau             310
# 188  182  Marshall Islands             212
# 189  183          Kiribati             188
# 190  184             Nauru             115
# 191  185            Tuvalu              43
#
# [191 rows x 3 columns]

# %% [markdown]
# <img src="./table_2018.PNG" width="500" height="500">
